# %% [markdown]
# # AIMO-3 Audit Notebook\nLocal/offline checks only. Do not submit this notebook.\n

# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# TOP CELL (SUBMISSION CELL)\n

# %%
C:\Users\aureon\aimo3_competition_only\audit_local\devils_advocate_cell.py
